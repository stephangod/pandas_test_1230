# %%
import numpy as np
import pandas as pd

# %%
print("np.__version__", np.__version__)
print("pd.__version__", pd.__version__)
print("OK")
# Out:
# np.__version__ 2.4.0
# pd.__version__ 2.3.3
# OK

# %%
test_list= [7,8,9,10,2,4,5,6,7,9]
df = pd.array(test_list)
print(df)
# Out:
# <IntegerArray>
# [7, 8, 9, 10, 2, 4, 5, 6, 7, 9]
# Length: 10, dtype: Int64

# %%
print(df.max())
print(df.mean())
# Out:
# 10
# 6.7
