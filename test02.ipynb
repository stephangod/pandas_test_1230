# %%
import numpy as np
import pandas as pd

# %%
print("np.__version__", np.__version__)
print("pd.__version__", pd.__version__)
print("OK")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 print("np.__version__", np.__verseion__)
#       2 print("pd.__version__", pd.__verseion__)
#       3 print("OK")
#
# File c:\Users\Donga\myproject\1230\.venv\Lib\site-packages\numpy\__init__.py:805, in __getattr__(attr)
#     802     import numpy.char as char
#     803     return char.chararray
# --> 805 raise AttributeError(f"module {__name__!r} has no attribute {attr!r}")
#
# AttributeError: module 'numpy' has no attribute '__verseion__'
